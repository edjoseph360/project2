# %%
import pandas as pd

# %%
cleandf=pd.read_csv('cleaned_df.csv')
faodf=pd.read_csv('fao.csv', encoding="latin")

# %%
faodf
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                   AFG          2  Afghanistan       2511
# 1                   AFG          2  Afghanistan       2805
# 2                   AFG          2  Afghanistan       2513
# 3                   AFG          2  Afghanistan       2513
# 4                   AFG          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472               ZWE        181     Zimbabwe       2948
# 21473               ZWE        181     Zimbabwe       2960
# 21474               ZWE        181     Zimbabwe       2960
# 21475               ZWE        181     Zimbabwe       2961
# 21476               ZWE        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
faodf.columns = ['Area Abbreviation', 'Area Code', 'Country', 'Item Code', 'Item',
       'Element Code', 'Element', 'Unit', 'latitude', 'longitude', 'Y1961',
       'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969',
       'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977',
       'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985',
       'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991', 'Y1992', 'Y1993',
       'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001',
       'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009',
       'Y2010', 'Y2011', 'Y2012', 'Y2013']

faodf=faodf.drop(columns=['latitude', 'longitude'])

# %%
faodf
# Out:
#       Area Abbreviation  Area Code      Country  Item Code  \
# 0                   AFG          2  Afghanistan       2511
# 1                   AFG          2  Afghanistan       2805
# 2                   AFG          2  Afghanistan       2513
# 3                   AFG          2  Afghanistan       2513
# 4                   AFG          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472               ZWE        181     Zimbabwe       2948
# 21473               ZWE        181     Zimbabwe       2960
# 21474               ZWE        181     Zimbabwe       2960
# 21475               ZWE        181     Zimbabwe       2961
# 21476               ZWE        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit   Y1961  \
# 0            Wheat and products          5142    Food  1000 tonnes  1928.0
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes   183.0
# ...

# %%
cleandf.columns
# Out:
# Index(['Unnamed: 0', 'product_name', 'categories_en', 'energy_100g',
#        'proteins_100g', 'carbohydrates_100g', 'fat_100g', 'saturated-fat_100g',
#        'fiber_100g', 'sugars_100g', 'countries', 'countries_en', 'brands',
#        'brands_tags', 'categories', 'categories_tags', 'categories_en.1',
#        'cholesterol_100g', 'trans-fat_100g', 'main_category_en'],
#       dtype='object')

# %%
cleandf = cleandf.drop(columns=['categories', 'countries', 'categories_en.1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-af4b552006f8> in <module>
# ----> 1 cleandf = cleandf.drop(columns=['categories', 'countries', 'categories_en.1', 'categories_tags'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
cleandf
# Out:
#       Unnamed: 0                     product_name  \
# 0            185     Chaussons tressés aux pommes
# 1            186              Pain Burger Artisan
# 2            190                  Quiche Lorraine
# 3            321            Sea Salt Potato Chips
# 4            505    Clam Chowder A Condensed Soup
# ...          ...                              ...
# 2425      419421             Malt-O Meal Original
# 2426      419540                      Apple Zings
# 2427      419565                  Tootie Fruities
# 2428      419954  Peanut butter, organic, smooth
# 2429      420072         100% Organic Apple Juice
#
#                                           categories_en  energy_100g  \
# 0             Sugary snacks,Biscuits and cakes,Pastries       1090.0
# 1                                           fr:Boulange       1160.0
# 2     Meals,Pizzas pies and quiches,Quiches,fr:Quich...        478.0
# 3                                 Chips and fries,Chips       2243.0
# ...

# %%
cleandf.columns = ['Unnamed: 0', 'product_name', 'categories_en', 'energy_100g',
       'proteins_100g', 'carbohydrates_100g', 'fat_100g', 'saturated-fat_100g',
       'fiber_100g', 'sugars_100g', 'Country', 'brands', 'brands_tags',
       'categories_tags', 'cholesterol_100g', 'trans-fat_100g',
       'main_category_en']
cleandf
# Out:
#       Unnamed: 0                     product_name  \
# 0            185     Chaussons tressés aux pommes
# 1            186              Pain Burger Artisan
# 2            190                  Quiche Lorraine
# 3            321            Sea Salt Potato Chips
# 4            505    Clam Chowder A Condensed Soup
# ...          ...                              ...
# 2425      419421             Malt-O Meal Original
# 2426      419540                      Apple Zings
# 2427      419565                  Tootie Fruities
# 2428      419954  Peanut butter, organic, smooth
# 2429      420072         100% Organic Apple Juice
#
#                                           categories_en  energy_100g  \
# 0             Sugary snacks,Biscuits and cakes,Pastries       1090.0
# 1                                           fr:Boulange       1160.0
# 2     Meals,Pizzas pies and quiches,Quiches,fr:Quich...        478.0
# 3                                 Chips and fries,Chips       2243.0
# ...

# %%
newdf = pd.merge(cleandf, faodf, on='Country')
newdf
# Out:
#        Unnamed: 0                  product_name  \
# 0             185  Chaussons tressés aux pommes
# 1             185  Chaussons tressés aux pommes
# 2             185  Chaussons tressés aux pommes
# 3             185  Chaussons tressés aux pommes
# 4             185  Chaussons tressés aux pommes
# ...           ...                           ...
# 33626      362989          Mister potato crisps
# 33627      362989          Mister potato crisps
# 33628      362989          Mister potato crisps
# 33629      362989          Mister potato crisps
# 33630      362989          Mister potato crisps
#
#                                         categories_en  energy_100g  \
# 0           Sugary snacks,Biscuits and cakes,Pastries       1090.0
# 1           Sugary snacks,Biscuits and cakes,Pastries       1090.0
# 2           Sugary snacks,Biscuits and cakes,Pastries       1090.0
# 3           Sugary snacks,Biscuits and cakes,Pastries       1090.0
# ...

# %%
newdf.to_csv('newdf.csv')
